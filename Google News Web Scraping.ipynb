# %% [markdown]
# # Google News Web Scraping

# %%
import requests
import pandas as pd
import feedparser

def get_news_data(keyword):
    # Construct the RSS feed URL for Google News
    url = f"https://news.google.com/rss/search?q={keyword}&hl=en-US&gl=US&ceid=US:en"

    # Send a request to the RSS feed URL
    response = requests.get(url)
    
    # Parse the RSS feed
    feed = feedparser.parse(response.content)

    # List to store news results
    news_results = []

    # Extract information from each entry in the feed
    for entry in feed.entries:
        # Extract title and remove source name (usually in parentheses at the end)
        title = entry.title.split(' - ')[0] if 'title' in entry else 'No Title'  # Take only the part before ' - '
        published = entry.published if 'published' in entry else 'No Date'
        source = entry.source.title if 'source' in entry else 'No Source'

        news_results.append({
            'pubDate': published,
            'title': title,
        })

    return news_results

# Example usage
keyword = "AAPL"
news_data = get_news_data(keyword)

# Convert the collected data into a pandas DataFrame
df = pd.DataFrame(news_data)

# Modify the 'pubDate' column to include only year, month, and date in date format
df['pubDate'] = pd.to_datetime(df['pubDate']).dt.strftime('%Y-%m-%d')

df.sort_values(by='pubDate', inplace=True)
df = df.reset_index(drop=True)

# Display the DataFrame with all rows and columns
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df)
# Out:
#        pubDate                                              title
# 0   2025-01-31  Jim Cramer on Apple Inc (AAPL): ‘I Need To Kno...
# 1   2025-02-12  Apple (AAPL) Stock: Recent News and Rating Change
# 2   2025-02-12  Apple (AAPL) Robotics Vision Takes Shape-Here'...
# 3   2025-02-13  Apple Inc. (AAPL): Among Lee Munder Capital Gr...
# 4   2025-02-13  Apple (AAPL) Shares Rise Ahead of “New Family ...
# 5   2025-02-15  Apple Inc. (AAPL): Among the Best Forever Stoc...
# 6   2025-02-17  Apple Inc. (AAPL): Among the Best Streaming Se...
# 7   2025-02-18  Apple (AAPL) Gains Analyst Confidence with Upc...
# 8   2025-02-18  Apple Stock Price in 5 Years: AAPL Shares Have...
# 9   2025-02-18  Is Apple Inc. (AAPL) the Most Profitable Tech ...
# 10  2025-02-18  Apple Inc. (AAPL) Teases New Product Launch wi...
# 11  2025-02-20       Is Apple Stock A Buy After iPhone 16e Debut?
# 12  2025-02-23  Is Apple Inc. (AAPL) the Top Stock to Buy Acco...
# 13  2025-02-25  Is Apple Inc. (AAPL) Buying Back Its Stock in ...
# 14  2025-02-26  AAPL, NVDA, TSLA: Magnificent 7 Stocks Fall in...
# 15  2025-02-26  Apple Inc. (AAPL): Among the Best Fortune 500 ...
# 16  2025-02-28  Apple Inc. (AAPL) Maintained at ‘Buy’ as iPhon...
# 17  2025-02-28  Jim Cramer on Apple Inc. (AAPL): ‘It’s Very Ha...
# 18  2025-03-01  Is Apple Inc. (AAPL) The Best Money Making Sto...
# 19  2025-03-01  Apple Inc. (AAPL): Among Best Stocks To Invest...
# 20  2025-03-04  Apple (AAPL) Makes an Interesting Gamble on th...
# 21  2025-03-04  Apple (AAPL): Analysts Warn Two Things Threate...
# 22  2025-03-04  Jefferies Analysts Warn of Weaker iPhone 16e D...
# 23  2025-03-04  Apple (AAPL) Is the Best Technology Stock to O...
# 24  2025-03-04  Wedbush Sticks to Buy Rating on Apple (AAPL) S...
# 25  2025-03-04  iPad Air, iPad Get Upgrades at Apple (NASDAQ:A...
# 26  2025-03-05  Qualcomm (QCOM) Launches X85 Modem to Outperfo...
# 27  2025-03-05          Apple (AAPL) Launches Cheaper MacBook Air
# 28  2025-03-05  Apple Debuts New MacBook Air, Mac Studio With ...
# 29  2025-03-05  Apple (NasdaqGS:AAPL) Unveils Faster iPad Air ...
# 30  2025-03-05  Apple Inc. (AAPL): Among the Best Stocks To In...
# 31  2025-03-05        Apple (AAPL) introduces the new MacBook Air
# 32  2025-03-05                Apple (AAPL) unveils new Mac Studio
# 33  2025-03-05  Apple (AAPL): Alibaba Partnership Sparks Optim...
# 34  2025-03-05  AAPL, NVDA, or PLTR: Which Tech Stock Is the M...
# 35  2025-03-06  BofA Reiterates ‘Buy’ on Apple Inc. (AAPL) as ...
# 36  2025-03-06        Apple (AAPL) Introduces M3-Powered iPad Air
# 37  2025-03-06  Apple Is Down for the Year—Opportunity or Time...
# 38  2025-03-06  A Foldable iPhone from Apple (AAPL) Is Coming,...
# 39  2025-03-06  Apple likely to launch first foldable iPhone i...
# 40  2025-03-06  April 25th Options Now Available For Apple (AAPL)
# 41  2025-03-07  Apple Inc. (NASDAQ:AAPL) Shares Sold by City H...
# 42  2025-03-07  Live Nasdaq Composite: Stocks Lack Conviction,...
# 43  2025-03-07  My Legacy Advisors LLC Buys 1,402 Shares of Ap...
# 44  2025-03-07  Live Nasdaq Composite: Stocks Lack Conviction,...
# 45  2025-03-07       Will Trump Tariffs Take Apple Stock To $160?
# 46  2025-03-07   Notable Friday Option Activity: AAPL, AMZN, MSFT
# 47  2025-03-07  Apple says more personalized version of Siri i...
# 48  2025-03-07  Apple (AAPL) Beats Stock Market Upswing: What ...
# 49  2025-03-07  Apple: Dog Collar Working As Planned, Just In ...
# 50  2025-03-07  Is Apple Inc. (AAPL) Among the Best Warren Buf...
# 51  2025-03-07  Apple Inc. (AAPL): Jim Cramer Cautions – ‘I Co...
# 52  2025-03-07  Apple (AAPL) Clears Hurdle to Sell iPhone 16 i...
# 53  2025-03-07  Apple Inc. (AAPL) DCF Valuation: Is The Stock ...
# 54  2025-03-08          Could Apple Be a Millionaire-Maker Stock?
# 55  2025-03-08  Apple: The iPhone Lesson I’ve Learned (NASDAQ:...
# 56  2025-03-08  Apple Inc. (AAPL) Unveils Most Powerful Mac St...
# 57  2025-03-08  Apple (AAPL) Eyes 2026 Launch for $2000+ Folda...
# 58  2025-03-08  Apple Inc. (AAPL) Unveils AI-Powered MacBook A...
# 59  2025-03-08  Diversify Wealth Management LLC Purchases 37,0...
# 60  2025-03-09  Cove Private Wealth LLC Increases Holdings in ...
# 61  2025-03-09  AMI Investment Management Inc. Sells 53 Shares...
# 62  2025-03-09  Apple Inc. (NASDAQ:AAPL) Shares Acquired by Un...
# 63  2025-03-09  Apple Breaks Tradition With A Flood Of New Rel...
# 64  2025-03-09  Lionsbridge Wealth Management LLC Trims Stake ...
# 65  2025-03-09  Analyst: Apple Inc (AAPL) May Have to Pass On ...
# 66  2025-03-09  Apple Inc. (NASDAQ:AAPL) is Overbrook Manageme...
# 67  2025-03-09                           Apple Stock To Fall 30%?
# 68  2025-03-09  Maltin Wealth Management Inc. Buys 1,365 Share...
# 69  2025-03-09  Apple Inc. (NASDAQ:AAPL) Shares Purchased by F...
# 70  2025-03-09  Amplius Wealth Advisors LLC Purchases 600 Shar...
# 71  2025-03-09  Apple Inc. (NASDAQ:AAPL) is Bridgewater Adviso...
# 72  2025-03-09  Apple Inc. (NASDAQ:AAPL) Position Trimmed by F...
# 73  2025-03-09  Corundum Group Inc. Has $6.97 Million Position...
# 74  2025-03-09  Union Savings Bank Sells 649 Shares of Apple I...
# 75  2025-03-09  McCarthy & Cox Cuts Stake in Apple Inc. (NASDA...
# 76  2025-03-09  Gemmer Asset Management LLC Sells 820 Shares o...
# 77  2025-03-09  Apple Inc. (NASDAQ:AAPL) is MassMutual Private...
# 78  2025-03-09  Apple's Tumultuous Week – From Siri Delays, Le...
# 79  2025-03-09  Apple Inc. (NASDAQ:AAPL) Stock Position Cut by...
# 80  2025-03-09  Ervin Investment Management LLC Cuts Position ...
# 81  2025-03-09  Penn Davis Mcfarland Inc. Purchases 621 Shares...
# 82  2025-03-09  Apple Inc. (NASDAQ:AAPL) Stake Lessened by Gui...
# 83  2025-03-10  Central Bank & Trust Co. Has $21.91 Million St...
# 84  2025-03-10  Mountain Pacific Investment Advisers LLC Has $...
# 85  2025-03-10  Leonard Rickey Investment Advisors P.L.L.C. Se...
# 86  2025-03-10  Addenda Capital Inc. Has $37.70 Million Positi...
# 87  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Sold by Koshin...
# 88  2025-03-10  Abacus Wealth Partners LLC Decreases Holdings ...
# 89  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Sold by Sky In...
# 90  2025-03-10  Hoese & Co LLP Acquires 2,160 Shares of Apple ...
# 91  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Sold by Wealth...
# 92  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Purchased by P...
# 93  2025-03-10  CMH Wealth Management LLC Acquires 935 Shares ...
# 94  2025-03-10  Apple Inc. (NASDAQ:AAPL) Holdings Lowered by S...
# 95  2025-03-10  Priebe Wealth Holdings LLC Raises Stock Positi...
# 96  2025-03-10  Apple Inc. (NASDAQ:AAPL) is Regent Peak Wealth...
# 97  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Sold by Relian...
# 98  2025-03-10  Apple Inc. (NASDAQ:AAPL) is Culbertson A N & C...
# 99  2025-03-10  Apple’s (AAPL) AI Struggles Deepen as Siri Upg...

# %%
df = df[df['pubDate']>='2025-02-12']
df
# Out:
#        pubDate                                              title
# 1   2025-02-12  Apple (AAPL) Stock: Recent News and Rating Change
# 2   2025-02-12  Apple (AAPL) Robotics Vision Takes Shape-Here'...
# 3   2025-02-13  Apple Inc. (AAPL): Among Lee Munder Capital Gr...
# 4   2025-02-13  Apple (AAPL) Shares Rise Ahead of “New Family ...
# 5   2025-02-15  Apple Inc. (AAPL): Among the Best Forever Stoc...
# ..         ...                                                ...
# 95  2025-03-10  Priebe Wealth Holdings LLC Raises Stock Positi...
# 96  2025-03-10  Apple Inc. (NASDAQ:AAPL) is Regent Peak Wealth...
# 97  2025-03-10  Apple Inc. (NASDAQ:AAPL) Shares Sold by Relian...
# 98  2025-03-10  Apple Inc. (NASDAQ:AAPL) is Culbertson A N & C...
# 99  2025-03-10  Apple’s (AAPL) AI Struggles Deepen as Siri Upg...
#
# [99 rows x 2 columns]

# %%
df.to_csv('apple_news_2025-02-12_to_2025-03-10.csv', index=False)
